# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd

# %%
contry={'India':[122,232,312,412],'China':[223,233,435,967]}
df = pd.DataFrame(contry)
df
# Out:
#    India  China
# 0    122    223
# 1    232    233
# 2    312    435
# 3    412    967

# %%
s=df.plot(kind='line')
# plt.plot(scalex=5,scaley=5,data='o')
plt.ylabel("population")
plt.xlabel('year')
plt.show()
